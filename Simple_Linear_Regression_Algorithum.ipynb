# %% [markdown]
# Import the relevent libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# Generate random input data to train on

# %%
observations = 1000
xs = np.random.uniform(low=-10, high=10, size=(observations,1))
zs = np.random.uniform(-10,10,(observations,1))
inputs = np.column_stack((xs,zs))

print(inputs.shape)
# Out:
# (1000, 2)

# %% [markdown]
# Create the targets we will aim it

# %%
noise = np.random.uniform(-1,1,(observations,1))

targets = 2*xs - 3*zs + 5 + noise
print(targets.shape)
# Out:
# (1000, 1)

# %% [markdown]
# Plot the training data

# %%
targets = targets.reshape(observations,)
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.plot(xs, zs, targets)
ax.set_xlabel('xs')
ax.set_ylabel('zs')
ax.set_zlabel('targets')
ax.view_init(azim=100)
plt.show()
targets = targets.reshape(observations,1)

# %% [markdown]
# Initalize variables

# %%
init_range = 0.1
weights = np.random.uniform(-init_range, init_range, (2,1))

biases = np.random.uniform(-init_range, init_range, size=1)

print(weights)
print(biases)
# Out:
# [[0.09340085]
#  [0.00766435]]
# [0.07394182]

# %% [markdown]
# Set Learning rate

# %%
learning_rate = 0.02

# %% [markdown]
# Train the model

# %%
for i in range(100):
    outputs = np.dot(inputs, weights) +biases
    deltas = outputs - targets
    
    loss = np.sum(deltas ** 2) / 2 / observations
    
    print(loss)
    
    delats_scaled = deltas / observations
    
    weights = weights - learning_rate * np.dot(inputs.T, delats_scaled)
    biases = biases - learning_rate * np.sum(delats_scaled)
# Out:
# 218.64530708490253
# 37.26313176736963
# 14.542935710386823
# 11.250319137320595
# 10.452618241035593
# 9.997841179855339
# 9.60292867240851
# 9.229327015395077
# 8.871261145621641
# 8.527438572305698
# 8.197202975839536
# 7.88000495072959
# 7.575328038661542
# 7.2826777367972575
# 7.0015792809257364
# 6.7315766778921935
# 6.472231938322627
# 6.223124362277857
# 5.983849856269903
# 5.754020277680482
# 5.533262805119252
# 5.32121933364472
# 5.117545893858887
# 4.9219120939322725
# 4.734000583654003
# 4.553506539637547
# 4.380137170847043
# 4.213611243642058
# 4.053658625570351
# 3.900019847168595
# 3.7524456810602222
# 3.610696737667604
# 3.4745430768827688
# 3.3437638350667274
# 3.218146866772301
# 3.097488400609307
# 2.981592708693835
# 2.8702717891454204
# 2.7633450611170556
# 2.660639071863349
# 2.5619872153716434
# 2.4672294620996325
# 2.3762120993811333
# 2.2887874820788348
# 2.2048137930796075
# 2.124154813243801
# 2.046679700435397
# 1.9722627772745347
# 1.9007833272681178
# ...

# %% [markdown]
# Print weights and biases and see if they worked correctly

# %%
print(weights, biases)
# Out:
# [[ 2.00172529]
#  [-2.99707185]] [4.33793093]

# %% [markdown]
# Plot last output vs targets

# %%
plt.plot(outputs, targets)
plt.xlabel('outputs')
plt.ylabel('targets')
plt.show()
